# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# We also provide a CVXPY-based code for users to choose their own MIP solvers
#
# In our paper, we used gurobipy directly. In this notebook, we show some examples of using a different MIP solver (GLPK via CVXOPT)
#
# For K=20 examples, we use GLPK_MI
#
# For K=50 examples, we use gurobipy (via CVXPY) and SCIP

# %%
import cvxpy as cp
from algo.cvxpy_based import mdkp, mwbis
from algo.normal import count_unique_words
import numpy as np

# %%
import pickle
info = pickle.load(open("play_data/ctm20_20NewsGroup_min0.01.pkl", 'rb'))

# %%
choices = mwbis(info['topics'], info['total_score'], final_num_topics=20, epsilon=0, 
                solver=cp.GLPK_MI, solver_options={'reltol':0.02, 'max_iters':100})

new_scores = np.array(info["total_score"])[choices]
print(new_scores)
print("NPMI:", new_scores.mean())
print('TU:', count_unique_words(np.array(info["topics"])[choices])/(20*10))
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.2.1
# ===============================================================================
# (CVXPY) Oct 19 05:02:19 PM: Your problem has 988 variables, 89530 constraints, and 0 parameters.
# (CVXPY) Oct 19 05:02:22 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 19 05:02:22 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 19 05:02:22 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 19 05:02:25 PM: Compiling problem (target solver=GLPK_MI).
# (CVXPY) Oct 19 05:02:25 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> GLPK_MI
# (CVXPY) Oct 19 05:02:25 PM: Applying reduction FlipObjective
# (CVXPY) Oct 19 05:02:25 PM: Applying reduction Dcp2Cone
# (CVXPY) Oct 19 05:02:36 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 19 05:02:36 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Oct 19 05:04:00 PM: Applying reduction GLPK_MI
# (CVXPY) Oct 19 05:04:23 PM: Finished problem compilation (took 1.218e+02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 19 05:04:23 PM: Invoking solver GLPK_MI  to obtain a solution.
#       0: obj =  -1.231375481e+00 inf =   5.111e+03 (269)
#     141: obj =   1.158791072e+00 inf =   6.532e-14 (0) 1
# *   469: obj =  -3.331757573e+00 inf =   0.000e+00 (0) 3
# +   469: mip =     not found yet >=              -inf        (1; 0)
# +   469: >>>>>  -3.331757573e+00 >=  -3.331757573e+00   0.0% (1; 0)
# +   469: mip =  -3.331757573e+00 >=     tree is empty   0.0% (0; 1)
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 19 05:04:27 PM: Problem status: optimal
# (CVXPY) Oct 19 05:04:27 PM: Optimal value: 3.332e+00
# (CVXPY) Oct 19 05:04:27 PM: Compilation took 1.218e+02 seconds
# (CVXPY) Oct 19 05:04:27 PM: Solver (including time spent in interface) took 3.209e+00 seconds
# [0.18182261 0.18677336 0.13158431 0.25701725 0.18520209 0.10962344
#  0.21411804 0.17733381 0.0829693  0.18741008 0.07866596 0.06358849
#  0.06255149 0.09784393 0.08240757 0.2735388  0.25914103 0.21782109
#  0.260014   0.22233093]
# NPMI: 0.1665878786426141
# TU: 1.0

# %%
choices = mdkp(info['topics'], info['total_score'], final_num_topics=20, epsilon=0.90*20*10, 
                solver=cp.GLPK_MI, solver_options={'reltol':0.02, 'max_iters':100})
new_scores = np.array(info["total_score"])[choices]
print(new_scores)
print("NPMI:", new_scores.mean())
print('TU:', count_unique_words(np.array(info["topics"])[choices])/(20*10))
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.2.1
# ===============================================================================
# (CVXPY) Oct 19 05:04:29 PM: Your problem has 1902 variables, 916 constraints, and 0 parameters.
# (CVXPY) Oct 19 05:04:29 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 19 05:04:29 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 19 05:04:29 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 19 05:04:29 PM: Compiling problem (target solver=GLPK_MI).
# (CVXPY) Oct 19 05:04:29 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> GLPK_MI
# (CVXPY) Oct 19 05:04:29 PM: Applying reduction FlipObjective
# (CVXPY) Oct 19 05:04:29 PM: Applying reduction Dcp2Cone
# (CVXPY) Oct 19 05:04:29 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 19 05:04:29 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Oct 19 05:04:30 PM: Applying reduction GLPK_MI
# (CVXPY) Oct 19 05:04:30 PM: Finished problem compilation (took 1.261e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 19 05:04:30 PM: Invoking solver GLPK_MI  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 19 05:04:31 PM: Problem status: optimal
#       0: obj =  -1.231375481e+00 inf =   1.990e+02 (2)
# (CVXPY) Oct 19 05:04:31 PM: Optimal value: 3.643e+00
#     750: obj =   5.493362459e-01 inf =   2.051e-13 (0) 2
# *  1967: obj =  -3.643246943e+00 inf =   0.000e+00 (0) 8
# +  1967: mip =     not found yet >=              -inf        (1; 0)
# +  1967: >>>>>  -3.643246943e+00 >=  -3.643246943e+00   0.0% (1; 0)
# +  1967: mip =  -3.643246943e+00 >=     tree is empty   0.0% (0; 1)
# (CVXPY) Oct 19 05:04:31 PM: Compilation took 1.261e+00 seconds
# (CVXPY) Oct 19 05:04:31 PM: Solver (including time spent in interface) took 3.520e-01 seconds
# [0.18182261 0.19933727 0.18677336 0.25701725 0.18520209 0.10962344
#  0.15275139 0.20082495 0.21411804 0.24052793 0.10905341 0.10638845
#  0.0829693  0.18741008 0.07866596 0.1770566  0.2735388  0.21782109
#  0.260014   0.22233093]
# NPMI: 0.18216234715095503
# TU: 0.955

# %%
import pickle
info = pickle.load(open("play_data/ctm50_20NewsGroup_min0.01.pkl", 'rb'))

# %%
choices = mwbis(info['topics'], info['total_score'], final_num_topics=50, epsilon=1, 
                solver=cp.GUROBI, solver_options={'MIPGap':0.05, 'TimeLimit':1000})
new_scores = np.array(info["total_score"])[choices]
print(new_scores)
print("NPMI:", new_scores.mean())
print('TU:', count_unique_words(np.array(info["topics"])[choices])/(50*10))
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.2.1
# ===============================================================================
# (CVXPY) Oct 19 08:36:08 PM: Your problem has 1414 variables, 51165 constraints, and 0 parameters.
# (CVXPY) Oct 19 08:36:10 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 19 08:36:10 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 19 08:36:10 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 19 08:36:12 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Oct 19 08:36:12 PM: Reduction chain: FlipObjective -> CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> GUROBI
# (CVXPY) Oct 19 08:36:12 PM: Applying reduction FlipObjective
# (CVXPY) Oct 19 08:36:12 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 19 08:36:12 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 19 08:36:18 PM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 19 08:36:38 PM: Applying reduction GUROBI
# (CVXPY) Oct 19 08:36:39 PM: Finished problem compilation (took 2.885e+01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 19 08:36:39 PM: Invoking solver GUROBI  to obtain a solution.
# Set parameter TokenServer to value "nas.nodes.preferred.ai"
# Set parameter QCPDual to value 1
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 1000
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 64 physical cores, 128 logical processors, using up to 32 threads
# Optimize a model with 51165 rows, 1414 columns and 115257 nonzeros
# Model fingerprint: 0x33e93779
# Variable types: 0 continuous, 1414 integer (1414 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-05, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 0.5114718
# Presolve removed 46449 rows and 1 columns
# Presolve time: 0.52s
# Presolved: 4716 rows, 1413 columns, 64047 nonzeros
# Variable types: 0 continuous, 1413 integer (1413 binary)
# Found heuristic solution: objective -5.0886632
#
# Root relaxation: objective -7.241601e+00, 504 iterations, 0.03 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -7.24160    0  129   -5.08866   -7.24160  42.3%     -    0s
# H    0     0                      -6.2800940   -7.24160  15.3%     -    0s
# H    0     0                      -6.4131587   -7.24160  12.9%     -    0s
# H    0     0                      -6.6719411   -7.24160  8.54%     -    0s
# H    0     0                      -6.7712209   -7.02351  3.73%     -    0s
#      0     0   -7.02351    0   97   -6.77122   -7.02351  3.73%     -    0s
#
# Cutting planes:
#   Gomory: 20
#   Clique: 54
#   Zero half: 79
#   RLT: 3
#
# Explored 1 nodes (802 simplex iterations) in 0.78 seconds (0.71 work units)
# Thread count was 32 (of 128 available processors)
#
# Solution count 6: -6.77122 -6.67194 -6.41316 ... 0.511472
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective -6.771220909522e+00, best bound -7.023505056017e+00, gap 3.7258%
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 19 08:36:39 PM: Problem status: optimal
# (CVXPY) Oct 19 08:36:39 PM: Optimal value: 6.771e+00
# (CVXPY) Oct 19 08:36:39 PM: Compilation took 2.885e+01 seconds
# (CVXPY) Oct 19 08:36:39 PM: Solver (including time spent in interface) took 9.575e-01 seconds
# [0.09923488 0.05725519 0.09960592 0.08693322 0.04116109 0.07576233
#  0.06693093 0.0550812  0.15557814 0.04939097 0.09964926 0.10161573
#  0.05494365 0.13046844 0.04953801 0.06223993 0.07941264 0.0572433
#  0.15809858 0.24887168 0.25263338 0.13801338 0.04769222 0.21123636
#  0.23654112 0.10870901 0.12038578 0.17678126 0.14290611 0.11736729
#  0.12464151 0.14513956 0.21196298 0.15796266 0.11396555 0.19139398
#  0.17695306 0.12892962 0.2077402  0.2655323  0.18994246 0.11454765
#  0.1510836  0.12396891 0.16596197 0.23598874 0.19918049 0.09428867
#  0.10582362 0.2849324 ]
# NPMI: 0.1354244181904451
# TU: 0.886

# %%
choices = mdkp(info['topics'], info['total_score'], final_num_topics=50, epsilon=0.90*50*10, 
                solver=cp.SCIP, solver_options={'heuristics/proximity/mingap':0.05})
new_scores = np.array(info["total_score"])[choices]
print(new_scores)
print("NPMI:", new_scores.mean())
print('TU:', count_unique_words(np.array(info["topics"])[choices])/(50*10))
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.2.1
# ===============================================================================
# (CVXPY) Oct 19 08:36:55 PM: Your problem has 2648 variables, 1236 constraints, and 0 parameters.
# (CVXPY) Oct 19 08:36:55 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 19 08:36:55 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 19 08:36:55 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 19 08:36:55 PM: Compiling problem (target solver=SCIP).
# (CVXPY) Oct 19 08:36:55 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIP
# (CVXPY) Oct 19 08:36:55 PM: Applying reduction FlipObjective
# (CVXPY) Oct 19 08:36:55 PM: Applying reduction Dcp2Cone
# (CVXPY) Oct 19 08:36:56 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 19 08:36:56 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Oct 19 08:36:57 PM: Applying reduction SCIP
# (CVXPY) Oct 19 08:36:57 PM: Finished problem compilation (took 2.237e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 19 08:36:57 PM: Invoking solver SCIP  to obtain a solution.
# presolving:
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 19 08:37:19 PM: Problem status: optimal
#    (0.0s) symmetry computation started: requiring (bin +, int -, cont +), (fixed: bin -, int +, cont -)
#    (0.0s) symmetry computation finished: 3 generators found (max: 1500, log10 of symmetry group size: 0.9)
# presolving (0 rounds: 0 fast, 0 medium, 0 exhaustive):
#  0 deleted vars, 0 deleted constraints, 0 added constraints, 0 tightened bounds, 0 added holes, 0 changed sides, 0 changed coefficients
#  0 implications, 0 cliques
# presolved problem has 2648 variables (2648 bin, 0 int, 0 impl, 0 cont) and 1239 constraints
#    1236 constraints of type <linear>
#       3 constraints of type <orbitope>
# Presolving Time: 0.01
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#   0.2s|     1 |     0 |  2770 |     - |    36M |   0 |2648 |1239 |1236 |   0 |  0 |   0 |   0 |-7.451059e+00 |      --      |    Inf | unknown
#   0.3s|     1 |     0 |  2831 |     - |    39M |   0 |2648 |1239 |1239 |   3 |  1 |   0 |   0 |-7.426664e+00 |      --      |    Inf | unknown
#   0.5s|     1 |     0 |  2971 |     - |    41M |   0 |2648 |1239 |1242 |   6 |  3 |   0 |   0 |-7.414817e+00 |      --      |    Inf | unknown
#   0.5s|     1 |     0 |  3010 |     - |    42M |   0 |2648 |1239 |1243 |   7 |  4 |   0 |   0 |-7.413007e+00 |      --      |    Inf | unknown
#   0.6s|     1 |     0 |  3092 |     - |    42M |   0 |2648 |1239 |1246 |  10 |  5 |   0 |   0 |-7.402305e+00 |      --      |    Inf | unknown
#   0.7s|     1 |     0 |  3139 |     - |    43M |   0 |2648 |1239 |1247 |  11 |  6 |   0 |   0 |-7.400551e+00 |      --      |    Inf | unknown
#   0.8s|     1 |     0 |  3181 |     - |    44M |   0 |2648 |1239 |1249 |  13 |  7 |   0 |   0 |-7.398022e+00 |      --      |    Inf | unknown
#   0.9s|     1 |     0 |  3198 |     - |    44M |   0 |2648 |1239 |1250 |  14 |  8 |   0 |   0 |-7.396710e+00 |      --      |    Inf | unknown
#   0.9s|     1 |     0 |  3218 |     - |    44M |   0 |2648 |1239 |1251 |  15 |  9 |   0 |   0(CVXPY) Oct 19 08:37:19 PM: Optimal value: 7.367e+00
#  |-7.394907e+00 |      --      |    Inf | unknown
#   1.0s|     1 |     0 |  3244 |     - |    46M |   0 |2648 |1239 |1252 |  16 | 10 |   0 |   0 |-7.394414e+00 |      --      |    Inf | unknown
#   1.1s|     1 |     0 |  3292 |     - |    46M |   0 |2648 |1239 |1254 |  18 | 12 |   0 |   0 |-7.393160e+00 |      --      |    Inf | unknown
#   1.1s|     1 |     0 |  3311 |     - |    46M |   0 |2648 |1239 |1255 |  19 | 13 |   0 |   0 |-7.392871e+00 |      --      |    Inf | unknown
#   1.2s|     1 |     0 |  3327 |     - |    46M |   0 |2648 |1239 |1256 |  20 | 14 |   0 |   0 |-7.392687e+00 |      --      |    Inf | unknown
#   1.2s|     1 |     0 |  3341 |     - |    46M |   0 |2648 |1239 |1257 |  21 | 15 |   0 |   0 |-7.392492e+00 |      --      |    Inf | unknown
#   1.3s|     1 |     0 |  3366 |     - |    47M |   0 |2648 |1239 |1258 |  22 | 16 |   0 |   0 |-7.392308e+00 |      --      |    Inf | unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#   1.4s|     1 |     0 |  3388 |     - |    47M |   0 |2648 |1239 |1259 |  23 | 17 |   0 |   0 |-7.391970e+00 |      --      |    Inf | unknown
#   1.4s|     1 |     0 |  3403 |     - |    47M |   0 |2648 |1239 |1260 |  24 | 18 |   0 |   0 |-7.391483e+00 |      --      |    Inf | unknown
#   1.5s|     1 |     0 |  3441 |     - |    47M |   0 |2648 |1239 |1261 |  26 | 19 |   0 |   0 |-7.391073e+00 |      --      |    Inf | unknown
#   1.5s|     1 |     0 |  3479 |     - |    47M |   0 |2648 |1239 |1262 |  27 | 20 |   0 |   0 |-7.390265e+00 |      --      |    Inf | unknown
#   1.6s|     1 |     0 |  3487 |     - |    48M |   0 |2648 |1239 |1263 |  28 | 21 |   0 |   0 |-7.390124e+00 |      --      |    Inf | unknown
#   1.7s|     1 |     0 |  3517 |     - |    48M |   0 |2648 |1239 |1264 |  29 | 22 |   0 |   0 |-7.389354e+00 |      --      |    Inf | unknown
#   1.7s|     1 |     0 |  3526 |     - |    48M |   0 |2648 |1239 |1265 |  30 | 23 |   0 |   0 |-7.389293e+00 |      --      |    Inf | unknown
#   2.8s|     1 |     2 |  3526 |     - |    48M |   0 |2648 |1239 |1265 |  30 | 25 |   0 |  33 |-7.387041e+00 |      --      |    Inf | unknown
# * 7.9s|    12 |    11 |  4717 | 108.3 |strongbr|  11 |2648 |1239 |1263 |  30 |  1 |   0 | 259 |-7.382204e+00 |-7.246802e+00 |   1.87%| unknown
# * 8.2s|    13 |    10 |  4911 | 115.4 |strongbr|  11 |2648 |1249 |1263 |  30 |  2 |  10 | 284 |-7.382204e+00 |-7.246890e+00 |   1.87%| unknown
# * 8.3s|    13 |    10 |  4941 | 117.9 |strongbr|  11 |2648 |1249 |1263 |  30 |  3 |  10 | 290 |-7.382204e+00 |-7.252116e+00 |   1.79%| unknown
# * 8.9s|    15 |     8 |  5423 | 135.5 |strongbr|  11 |2648 |1297 |1263 |  30 |  2 |  58 | 360 |-7.382204e+00 |-7.258300e+00 |   1.71%| unknown
# * 9.0s|    15 |     7 |  5491 | 140.4 |strongbr|  11 |2648 |1298 |1263 |  30 |  3 |  59 | 371 |-7.382204e+00 |-7.260784e+00 |   1.67%|   0.35%
# *14.4s|    28 |    10 |  6898 | 124.9 |strongbr|  11 |2648 |1343 |1267 |  34 |  4 | 104 | 716 |-7.382204e+00 |-7.265005e+00 |   1.61%|   2.35%
# *15.1s|    28 |    10 |  6986 | 128.1 |strongbr|  11 |2648 |1349 |1267 |  34 |  8 | 110 | 757 |-7.382204e+00 |-7.268121e+00 |   1.57%|   2.35%
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
# *16.6s|    39 |    11 |  8212 | 123.3 |strongbr|  14 |2648 |1393 |1265 |  36 |  2 | 154 | 863 |-7.382204e+00 |-7.271069e+00 |   1.53%|   2.65%
# *16.9s|    44 |    10 |  8746 | 121.4 |    LP  |  16 |2648 |1421 |1265 |  36 |  3 | 182 | 903 |-7.382204e+00 |-7.271606e+00 |   1.52%|   3.42%
# *17.0s|    46 |     8 |  8971 | 121.0 |strongbr|  16 |2648 |1427 |1263 |  36 |  2 | 188 | 910 |-7.382204e+00 |-7.276221e+00 |   1.46%|   3.56%
# *18.3s|    51 |     8 |  9347 | 116.4 |    LP  |  16 |2648 |1427 |1263 |  36 |  1 | 188 | 969 |-7.382204e+00 |-7.328961e+00 |   0.73%|   5.64%
# *18.5s|    53 |     7 |  9543 | 115.7 |strongbr|  16 |2648 |1435 |1263 |  36 |  3 | 350 |(CVXPY) Oct 19 08:37:19 PM: Compilation took 2.237e+00 seconds
#  984 |-7.382204e+00 |-7.336914e+00 |   0.62%|   9.98%
# *20.0s|    74 |     8 | 11181 | 104.9 |strongbr|  16 |2648 |1512 |1263 |  36 |  1 | 427 |1097 |-7.382204e+00 |-7.343450e+00 |   0.53%|  10.95%
# *20.8s|    90 |     2 | 12378 |  99.5 |strongbr|  16 |2648 |1549 |1264 |  37 |  1 | 847 |1152 |-7.378239e+00 |-7.361121e+00 |   0.23%|  40.44%
# *21.2s|    98 |     2 | 12986 |  97.5 |    LP  |  16 |2648 |1560 |1264 |  37 |  2 | 858 |1182 |-7.378239e+00 |-7.367074e+00 |   0.15%|  47.94%
#  21.4s|   100 |     0 | 13503 | 100.8 |    51M |  16 |2648 |1569 |1263 |  37 |  1 |1758 |1192 |-7.367074e+00 |-7.367074e+00 |   0.00%|  77.11%
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 21.35
# Solving Nodes      : 100
# Primal Bound       : -7.36707376713126e+00 (15 solutions)
# Dual Bound         : -7.36707376713126e+00
# Gap                : 0.00 %
# (CVXPY) Oct 19 08:37:19 PM: Solver (including time spent in interface) took 2.181e+01 seconds
# [0.06931052 0.01178723 0.14933599 0.09960592 0.03537636 0.03500778
#  0.04039022 0.02325178 0.04939097 0.09964926 0.10161573 0.13046844
#  0.00669712 0.06223993 0.15387013 0.12724235 0.2081166  0.13801338
#  0.18667725 0.22759054 0.09792886 0.12038578 0.17678126 0.11736729
#  0.20255409 0.26747926 0.15835515 0.12464151 0.20994828 0.2681116
#  0.14930368 0.19656156 0.2080491  0.2079882  0.14133795 0.12892962
#  0.2077402  0.2655323  0.18994246 0.11454765 0.24488031 0.2239518
#  0.08915283 0.1510836  0.12396891 0.2322063  0.16596197 0.23598874
#  0.10582362 0.2849324 ]
# NPMI: 0.14734147534262523
# TU: 0.908
